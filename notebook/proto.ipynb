# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
frame = cv2.cvtColor(cv2.imread('../data/input_image_road.jpg'), cv2.COLOR_BGR2RGB)
plt.imshow(frame)
print(frame.shape)
# Out:
# (1080, 1920, 3)

# %%
map_image = cv2.cvtColor(cv2.imread('../data/map.jpg'), cv2.COLOR_BGR2RGB)
plt.imshow(map_image)
print(map_image.shape)
# Out:
# (500, 500, 3)

# %%
map_image = cv2.cvtColor(cv2.imread('../data/map.jpg'), cv2.COLOR_BGR2RGB)

x_offset=y_offset=50

frame[y_offset:y_offset + map_image.shape[0],x_offset:x_offset + map_image.shape[1]] = map_image

plt.imshow(frame)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-ecde797c848d> in <module>
#       3 x_offset=y_offset=50
#       4
# ----> 5 frame[map_image.shape[0]-y_offset:y_offset,x_offset:x_offset + map_image.shape[1]] = map_image
#       6
#       7 plt.imshow(frame)
#
# ValueError: could not broadcast input array from shape (500,500,3) into shape (0,500,3)
